# %% [markdown]
# <a href="https://colab.research.google.com/github/XxEgorikxX/University/blob/main/2.%20%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B8%D0%B5%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%8B/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%963_%D0%92%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B2_%D0%9E%D0%9E%D0%9F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Практическая работа №3. Введение в ООП**

# %% [markdown]
# ## **Задание №1. Создайте класс Sphere для представления сферы в трехмерном пространстве**

# %% [markdown]
# Обеспечьте следующие методы класса:
#
# 1. Конструктор, принимающий 4 действительных числа: радиус, и 3 координаты центра шара. Если конструктор вызывается без аргументов, создать объект сферы с единичным радиусом и центром в начале координат. Если конструктор вызывается с аргументом, создать объект сферы с соответствующим радиусом и центром в начале координат.
#
# 2. Метод get_volume (), который возвращает действительное число — объем шара, ограниченной текущей сферой.
#
# 3. Метод get_square (), который возвращает действительное число — площадь внешней поверхности сферы.
#
# 4. Метод get_radius (), который возвращает действительное число — радиус сферы.
#
# 5. Метод get_center (), который возвращает тьюпл с 3 действительными числами — координатами центра сферы в том же порядке, в каком они задаются в конструкторе.
#
# 6. Метод set_radius (r), который принимает 1 аргумент — действительное число, и меняет радиус текущей сферы, ничего не возвращая.
#
# 7. Метод set_center (x, y, z), который принимает 3 аргумента — действительных числа, и меняет координаты центра сферы, ничего не возвращая. Координаты задаются в том же порядке, что и в конструкторе.
#
# 8. Метод is_point_inside (x, y, z), который принимает 3 аргумента — действительных числа — координаты некоторой точки в пространстве (в том же порядке, что и в конструкторе), и возвращает логическое значение True или False в зависимости от того, находится эта точка внутри сферы.

# %%
# Тесты

s0 = Sphere(0.5) # test sphere creation with radius and default center
print(s0.get_center()) # (0.0, 0.0, 0.0)
print(s0.get_volume()) # 0.523598775598
print(s0.is_point_inside(0 , -1.5, 0)) # False
s0.set_radius(1.6)
print(s0.is_point_inside(0, -1.5, 0)) # True
print(s0.get_radius()) # 1.6

# %%
import math

class Sphere:


    def __init__(self, radius=1.0, x=0.0, y=0.0, z=0.0):

        if isinstance(radius,(int,float)) and radius < 0:
            raise ValueError("Radius cannot be negative.")

        if isinstance(radius, (int,float)):
            self._radius = radius
            self._center = (0.0, 0.0, 0.0)
        elif isinstance(radius, (tuple,list)) and len(radius) == 4:
            if radius[0] < 0:
                raise ValueError("Radius cannot be negative.")
            self._radius = radius[0]
            self._center = (radius[1],radius[2],radius[3])

        else:
            self._radius = 1.0
            self._center = (0.0, 0.0, 0.0)



    def get_volume(self):
        return (4/3) * math.pi * self._radius**3

    def get_square(self):
        return 4 * math.pi * self._radius**2

    def get_radius(self):
        return self._radius

    def get_center(self):
        return self._center

    def set_radius(self, r):
        if r < 0:
            raise ValueError("Radius cannot be negative.")
        self._radius = r

    def set_center(self, x, y, z):
        self._center = (x, y, z)

    def is_point_inside(self, x, y, z):
        distance = math.sqrt((x - self._center[0])**2 + (y - self._center[1])**2 + (z - self._center[2])**2)
        return distance < self._radius


# Примеры использования:
sphere1 = Sphere(2,1,2,3)  # Радиус 2, центр (1,2,3)
print(f"Объём сферы1: {sphere1.get_volume()}")
print(f"Площадь поверхности сферы1: {sphere1.get_square()}")
print(f"Центр сферы1: {sphere1.get_center()}")
print(f"Точка (1,2,2) внутри сферы1: {sphere1.is_point_inside(1,2,2)}")


sphere2 = Sphere(5) # Радиус 5, центр (0,0,0)
sphere2.set_center(10,10,10)
print(f"Центр сферы2: {sphere2.get_center()}")
sphere2.set_radius(7)
print(f"Радиус сферы2: {sphere2.get_radius()}")


sphere3 = Sphere() # Радиус 1, центр (0,0,0)
print(f"Объём сферы3: {sphere3.get_volume()}")

try:
  sphere4 = Sphere(-1)
except ValueError as e:
  print(f"Ошибка при создании сферы: {e}")

# %% [markdown]
# ## **Задание №2. Создайте класс SuperStr, который наследует стандартный класс str и содержит 2 новых метода:**

# %% [markdown]
# 1. Метод is_repeatance (s), который принимает 1 аргумент s и возвращает True или False в зависимости от того, может ли текущая строку быть получена целым количеством повторов строки s. Вернуть False, если s не является строкой. Считать, что пустая строка не содержит повторов.
#
# 2. Метод is_palindrom (), который возвращает True или False в зависимости от того, является ли строка [палиндромом](https://ru.wikipedia.org/wiki/Палиндром). Регистрами символов пренебрегать. Пустую строку считать палиндромом.

# %%
class SuperStr(str):

    def is_repeatance(self, s):
        if not isinstance(s, str):
            return False
        if not s:  # Empty string case
            return not self

        if len(self) % len(s) != 0:
            return False

        num_repetitions = len(self) // len(s)
        return self == s * num_repetitions

    def is_palindrom(self):
        processed_string = self.lower()
        return processed_string == processed_string[::-1]


# Примеры использования:
test_str1 = SuperStr("abcabcabc")
print(f"'{test_str1}' is a repeatance of 'abc': {test_str1.is_repeatance('abc')}")  # True
print(f"'{test_str1}' is a repeatance of 'ab': {test_str1.is_repeatance('ab')}")  # False
print(f"'{test_str1}' is a palindrome: {test_str1.is_palindrom()}")  # False

test_str2 = SuperStr("A man, a plan, a canal: Panama")
print(f"'{test_str2}' is a palindrome: {test_str2.is_palindrom()}")  # True

test_str3 = SuperStr("")
print(f"'{test_str3}' is a repeatance of 'abc': {test_str3.is_repeatance('abc')}")  # False
print(f"'{test_str3}' is a palindrome: {test_str3.is_palindrom()}")  # True

test_str4 = SuperStr("hello")
print(f"'{test_str4}' is a repeatance of 123: {test_str4.is_repeatance(123)}") #False

# %%
# Тесты

s = SuperStr("123123123123")
print(s.is_repeatance("123")) # True
print(s.is_repeatance("123123")) # True
print(s.is_repeatance("123123123123")) # True
print(s.is_repeatance("12312")) # False
print(s.is_repeatance(123)) # False
print(s.is_palindrom()) # False
print(s) # 123123123123 (строка)
print(int(s)) # 123123123123 (целое число)
print(s + "qwe") # 123123123123qwe
p = SuperStr("123_321")
print(p.is_palindrom()) # True

# %% [markdown]
# ## **Задание №3. В коде ниже представлен класс преподавателей и класс студентов (вы можете взять этот код за основу или написать свой).**

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []

    def rate_hw(self, student, course, grade):
        student.grades[course] = [grade]

# %%
best_student = Student('Ruoy', 'Eman', 'your_gender')
cool_mentor = Mentor('Some', 'Buddy')
cool_mentor.rate_hw(best_student, 'Python', 10)

print("Имя студента: ", best_student.name)
print("Имя преподавателя: ", cool_mentor.name)
print("Оценки студента по курсам: ", best_student.grades)
# Out:
# Имя студента:  Ruoy
# Имя преподавателя:  Some
# Оценки студента по курсам:  {'Python': [10]}

# %% [markdown]
# ### **3.1. Наследование**

# %% [markdown]
# * Класс Mentor должен стать родительским классом для преподавателей. От него нужно реализовать наследование классов Lecturer (лекторы) и Reviewer (эксперты, проверяющие домашние задания).
#
# > Имя, фамилю и список закрепленных курсов логично реализовать на уровне родительского класса.

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.courses_in_progress.append(course_name)

    def rate_lecturer(self, lecturer, course, grade):
        if isinstance(lecturer, Lecturer) and course in lecturer.courses_attached and course in self.courses_in_progress:
            if course in lecturer.grades:
                lecturer.grades[course] += [grade]
            else:
                lecturer.grades[course] = [grade]
        else:
            return 'Ошибка'

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за домашние задания: {self.average_grade()}\nКурсы в процессе изучения: {', '.join(self.courses_in_progress)}\nЗавершенные курсы: {', '.join(self.finished_courses)}"

    def average_grade(self):
        grades_sum = 0
        grades_count = 0
        for course, grades in self.grades.items():
            grades_sum += sum(grades)
            grades_count += len(grades)
        return grades_sum / grades_count if grades_count else 0


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []


class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}

    def __str__(self):
        average_grade = self.average_grade()
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за лекции: {average_grade}"

    def average_grade(self):
        grades_sum = 0
        grades_count = 0
        for course, grades in self.grades.items():
            grades_sum += sum(grades)
            grades_count += len(grades)
        return grades_sum / grades_count if grades_count else 0


class Reviewer(Mentor):
    def rate_hw(self, student, course, grade):
        if isinstance(student, Student) and course in self.courses_attached and course in student.courses_in_progress:
            if course in student.grades:
                student.grades[course] += [grade]
            else:
                student.grades[course] = [grade]
        else:
            return 'Ошибка'

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}"


best_student = Student('Ruoy', 'Eman', 'your_gender')
best_student.courses_in_progress += ['Python', 'Git']
cool_mentor = Mentor('Some', 'Buddy')
cool_reviewer = Reviewer('Some', 'Buddy')
cool_reviewer.courses_attached += ['Python']
cool_lecturer = Lecturer('Another', 'Buddy')
cool_lecturer.courses_attached += ['Python']

cool_reviewer.rate_hw(best_student, 'Python', 10)
cool_reviewer.rate_hw(best_student, 'Python', 9)
best_student.rate_lecturer(cool_lecturer,'Python',10)
best_student.rate_lecturer(cool_lecturer, 'Python', 9)
best_student.add_courses('Введение в программирование')

print(best_student)
print(cool_lecturer)
print(cool_reviewer)

# %% [markdown]
# ### **3.2. Атрибуты и взаимодействие классов**

# %% [markdown]
# * Реализуйте возможность проставления оценок студентам только Reviewer-ам (реализуйте такой метод).
#
# * Реализуйте метод выставления оценок лекторам у класса Student (оценки по 10-балльной шкале, хранятся в атрибуте-словаре у Lecturer, в котором ключи – названия курсов, а значения – списки оценок). Лектор при этом должен быть закреплен за тем курсом, на который записан студент (реализовать проверку).

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.courses_in_progress.append(course_name)

    def rate_lecturer(self, lecturer, course, grade):
        if isinstance(lecturer, Lecturer) and course in lecturer.courses_attached and course in self.courses_in_progress:
            if course in lecturer.grades:
                lecturer.grades[course] += [grade]
            else:
                lecturer.grades[course] = [grade]
        else:
            return 'Ошибка'

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за домашние задания: {self.average_grade()}\nКурсы в процессе изучения: {', '.join(self.courses_in_progress)}\nЗавершенные курсы: {', '.join(self.finished_courses)}"

    def average_grade(self):
        grades_sum = 0
        grades_count = 0
        for course, grades in self.grades.items():
            grades_sum += sum(grades)
            grades_count += len(grades)
        return grades_sum / grades_count if grades_count else 0


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []


class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}

    def __str__(self):
        average_grade = self.average_grade()
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за лекции: {average_grade}"

    def average_grade(self):
        grades_sum = 0
        grades_count = 0
        for course, grades in self.grades.items():
            grades_sum += sum(grades)
            grades_count += len(grades)
        return grades_sum / grades_count if grades_count else 0


class Reviewer(Mentor):
    def rate_hw(self, student, course, grade):
        if isinstance(student, Student) and course in self.courses_attached and course in student.courses_in_progress:
            if course in student.grades:
                student.grades[course] += [grade]
            else:
                student.grades[course] = [grade]
        else:
            return 'Ошибка'

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}"



best_student = Student('Ruoy', 'Eman', 'your_gender')
best_student.courses_in_progress += ['Python', 'Git']
cool_mentor = Mentor('Some', 'Buddy')
cool_reviewer = Reviewer('Some', 'Buddy')
cool_reviewer.courses_attached += ['Python']
cool_lecturer = Lecturer('Another', 'Buddy')
cool_lecturer.courses_attached += ['Python']

cool_reviewer.rate_hw(best_student, 'Python', 10)
cool_reviewer.rate_hw(best_student, 'Python', 9)
best_student.rate_lecturer(cool_lecturer,'Python',10)
best_student.rate_lecturer(cool_lecturer, 'Python', 9)
best_student.add_courses('Введение в программирование')

print(best_student)
print(cool_lecturer)
print(cool_reviewer)


#тест на среднюю оценку всех студентов в Python
student1 = Student('Ivan', 'Ivanov', 'm')
student1.courses_in_progress += ['Python']
cool_reviewer.rate_hw(student1, 'Python', 8)
cool_reviewer.rate_hw(student1, 'Python', 7)

students_list = [best_student,student1]

def average_grade_all_student(students_list, course):
    grades_sum = 0
    grades_count = 0
    for student in students_list:
      if course in student.grades:
        grades_sum += sum(student.grades[course])
        grades_count += len(student.grades[course])
    return grades_sum / grades_count if grades_count else 0

print(f"Средняя оценка всех студентов по курсу Python: {average_grade_all_student(students_list, 'Python')}")

lecturers_list = [cool_lecturer]

#тест на среднюю оценку всех лекторов по курсу Python
def average_grade_all_lecturer(lecturers_list, course):
    grades_sum = 0
    grades_count = 0
    for lecturer in lecturers_list:
      if course in lecturer.grades:
        grades_sum += sum(lecturer.grades[course])
        grades_count += len(lecturer.grades[course])
    return grades_sum / grades_count if grades_count else 0

print(f"Средняя оценка всех лекторов по курсу Python: {average_grade_all_lecturer(lecturers_list, 'Python')}")

# %% [markdown]
# ### **3.3. Полиморфизм и магические методы**

# %% [markdown]
# Перегрузите магический метод \_\_str__ у всех классов.
# У проверяющих он должен выводить информацию в следующем виде:
#
#
#
# ```
# print(some_reviewer)
# Имя: Some
# Фамилия: Buddy
# ```
#
# У лекторов:
#
#
#
# ```
# print(some_lecturer)
# Имя: Some
# Фамилия: Buddy
# Средняя оценка за лекции: 9.9
# ```
#
# А у студентов так:
#
#
#
# ```
# print(some_student)
# Имя: Ruoy
# Фамилия: Eman
# Средняя оценка за домашние задания: 9.9
# Курсы в процессе изучения: Python, Git
# Завершенные курсы: Введение в программирование
# ```

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.courses_in_progress.append(course_name)

    def rate_lecturer(self, lecturer, course, grade):
        if isinstance(lecturer, Lecturer) and course in lecturer.courses_attached and course in self.courses_in_progress:
            if course in lecturer.grades:
                lecturer.grades[course] += [grade]
            else:
                lecturer.grades[course] = [grade]
        else:
            return 'Ошибка'

    def __str__(self):
        average_grade = self.average_grade()
        courses_in_progress_str = ", ".join(self.courses_in_progress) or "отсутствуют"
        finished_courses_str = ", ".join(self.finished_courses) or "отсутствуют"
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за домашние задания: {average_grade:.1f}\nКурсы в процессе изучения: {courses_in_progress_str}\nЗавершенные курсы: {finished_courses_str}"

    def average_grade(self):
        grades_sum = 0
        grades_count = 0
        for grades in self.grades.values():
            grades_sum += sum(grades)
            grades_count += len(grades)
        return grades_sum / grades_count if grades_count else 0


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []


class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}

    def __str__(self):
        average_grade = self.average_grade()
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за лекции: {average_grade:.1f}"

    def average_grade(self):
        grades_sum = 0
        grades_count = 0
        for grades in self.grades.values():
            grades_sum += sum(grades)
            grades_count += len(grades)
        return grades_sum / grades_count if grades_count else 0


class Reviewer(Mentor):
    def rate_hw(self, student, course, grade):
        if isinstance(student, Student) and course in self.courses_attached and course in student.courses_in_progress:
            if course in student.grades:
                student.grades[course] += [grade]
            else:
                student.grades[course] = [grade]
        else:
            return 'Ошибка'

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}"



best_student = Student('Ruoy', 'Eman', 'your_gender')
best_student.courses_in_progress += ['Python', 'Git']
best_student.finished_courses = ['Введение в программирование']
cool_mentor = Mentor('Some', 'Buddy')
cool_reviewer = Reviewer('Some', 'Buddy')
cool_reviewer.courses_attached += ['Python']
cool_lecturer = Lecturer('Another', 'Buddy')
cool_lecturer.courses_attached += ['Python']

cool_reviewer.rate_hw(best_student, 'Python', 10)
cool_reviewer.rate_hw(best_student, 'Python', 9)
best_student.rate_lecturer(cool_lecturer,'Python',10)
best_student.rate_lecturer(cool_lecturer, 'Python', 9)


print(cool_reviewer)
print(cool_lecturer)
print(best_student)

# %% [markdown]
# **Реализуйте перегрузку других магических методов на Ваш выбор (не менее трёх), руководствуясь по смыслу контекстом представленных классов (студенты, преподаватели, оценки и т.д.)**

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.courses_in_progress.append(course_name)

    def rate_lecturer(self, lecturer, course, grade):
        if isinstance(lecturer, Lecturer) and course in lecturer.courses_attached and course in self.courses_in_progress:
            if course in lecturer.grades:
                lecturer.grades[course] += [grade]
            else:
                lecturer.grades[course] = [grade]
        else:
            return 'Ошибка'

    def __str__(self):
        average_grade = self.average_grade()
        courses_in_progress_str = ", ".join(self.courses_in_progress) or "отсутствуют"
        finished_courses_str = ", ".join(self.finished_courses) or "отсутствуют"
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за домашние задания: {average_grade:.1f}\nКурсы в процессе изучения: {courses_in_progress_str}\nЗавершенные курсы: {finished_courses_str}"

    def average_grade(self):
        grades_sum = 0
        grades_count = 0
        for grades in self.grades.values():
            grades_sum += sum(grades)
            grades_count += len(grades)
        return grades_sum / grades_count if grades_count else 0

    def __lt__(self, other): #Сравнение студентов по средней оценке
        if isinstance(other, Student):
          return self.average_grade() < other.average_grade()
        else:
          return False

    def __eq__(self, other): #Проверка на равенство студентов по имени и фамилии
        if isinstance(other, Student):
          return self.name == other.name and self.surname == other.surname
        else:
          return False


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []


class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}

    def __str__(self):
        average_grade = self.average_grade()
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за лекции: {average_grade:.1f}"

    def average_grade(self):
        grades_sum = 0
        grades_count = 0
        for grades in self.grades.values():
            grades_sum += sum(grades)
            grades_count += len(grades)
        return grades_sum / grades_count if grades_count else 0

    def __lt__(self, other): #Сравнение лекторов по средней оценке
        if isinstance(other, Lecturer):
          return self.average_grade() < other.average_grade()
        else:
          return False

    def __add__(self, other): #Сложение лекторов (сложение средней оценки)
      if isinstance(other, Lecturer):
        return self.average_grade() + other.average_grade()
      else:
        return 'Ошибка'


class Reviewer(Mentor):
    def rate_hw(self, student, course, grade):
        if isinstance(student, Student) and course in self.courses_attached and course in student.courses_in_progress:
            if course in student.grades:
                student.grades[course] += [grade]
            else:
                student.grades[course] = [grade]
        else:
            return 'Ошибка'

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}"


best_student = Student('Ruoy', 'Eman', 'your_gender')
best_student.courses_in_progress += ['Python', 'Git']
best_student.finished_courses = ['Введение в программирование']
cool_mentor = Mentor('Some', 'Buddy')
cool_reviewer = Reviewer('Some', 'Buddy')
cool_reviewer.courses_attached += ['Python']
cool_lecturer = Lecturer('Another', 'Buddy')
cool_lecturer.courses_attached += ['Python']
cool_lecturer2 = Lecturer('One', 'More')
cool_lecturer2.courses_attached += ['Python']

cool_reviewer.rate_hw(best_student, 'Python', 10)
cool_reviewer.rate_hw(best_student, 'Python', 9)
best_student.rate_lecturer(cool_lecturer,'Python',10)
best_student.rate_lecturer(cool_lecturer, 'Python', 9)
best_student.rate_lecturer(cool_lecturer2, 'Python', 8)
best_student.rate_lecturer(cool_lecturer2, 'Python', 7)


print(cool_reviewer)
print(cool_lecturer)
print(best_student)

student2 = Student('Another', 'One', 'other')
student2.courses_in_progress += ['Python', 'Git']
cool_reviewer.rate_hw(student2, 'Python', 6)
cool_reviewer.rate_hw(student2, 'Python', 5)

print(f"Лучший студент: {best_student > student2}")
print(f"Студенты равны: {best_student == student2}")
print(f"Сумма оценок лекторов: {cool_lecturer + cool_lecturer2}")

# %% [markdown]
# ### **3.4. Тестирование**
#
# Создайте по 2 экземпляра каждого класса, вызовите все созданные методы, а также реализуйте две функции:
#
# * для подсчета средней оценки за домашние задания по всем студентам в рамках конкретного курса (в качестве аргументов принимаем список студентов и название курса);
# * для подсчета средней оценки за лекции всех лекторов в рамках курса (в качестве аргумента принимаем список лекторов и название курса).

# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def add_courses(self, course_name):
        self.courses_in_progress.append(course_name)

    def rate_lecturer(self, lecturer, course, grade):
        if isinstance(lecturer, Lecturer) and course in lecturer.courses_attached and course in self.courses_in_progress:
            if course in lecturer.grades:
                lecturer.grades[course] += [grade]
            else:
                lecturer.grades[course] = [grade]
        else:
            return 'Ошибка'

    def __str__(self):
        average_grade = self.average_grade()
        courses_in_progress_str = ", ".join(self.courses_in_progress) or "отсутствуют"
        finished_courses_str = ", ".join(self.finished_courses) or "отсутствуют"
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за домашние задания: {average_grade:.1f}\nКурсы в процессе изучения: {courses_in_progress_str}\nЗавершенные курсы: {finished_courses_str}"

    def average_grade(self):
        grades_sum = 0
        grades_count = 0
        for grades in self.grades.values():
            grades_sum += sum(grades)
            grades_count += len(grades)
        return grades_sum / grades_count if grades_count else 0

    def __lt__(self, other):
        if isinstance(other, Student):
            return self.average_grade() < other.average_grade()
        else:
            return False

    def __eq__(self, other):
        if isinstance(other, Student):
            return self.name == other.name and self.surname == other.surname
        else:
            return False


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []


class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}

    def __str__(self):
        average_grade = self.average_grade()
        return f"Имя: {self.name}\nФамилия: {self.surname}\nСредняя оценка за лекции: {average_grade:.1f}"

    def average_grade(self):
        grades_sum = 0
        grades_count = 0
        for grades in self.grades.values():
            grades_sum += sum(grades)
            grades_count += len(grades)
        return grades_sum / grades_count if grades_count else 0

    def __lt__(self, other):
        if isinstance(other, Lecturer):
            return self.average_grade() < other.average_grade()
        else:
            return False

    def __add__(self, other):
        if isinstance(other, Lecturer):
            return self.average_grade() + other.average_grade()
        else:
            return 'Ошибка'


class Reviewer(Mentor):
    def rate_hw(self, student, course, grade):
        if isinstance(student, Student) and course in self.courses_attached and course in student.courses_in_progress:
            if course in student.grades:
                student.grades[course] += [grade]
            else:
                student.grades[course] = [grade]
        else:
            return 'Ошибка'

    def __str__(self):
        return f"Имя: {self.name}\nФамилия: {self.surname}"


# Создание экземпляров
student1 = Student('Ruoy', 'Eman', 'male')
student2 = Student('Ivan', 'Ivanov', 'male')
lecturer1 = Lecturer('Some', 'Buddy')
lecturer2 = Lecturer('Another', 'Buddy')
reviewer1 = Reviewer('One', 'More')
reviewer2 = Reviewer('Some', 'Buddy')


# Пример использования методов
student1.add_courses('Python')
student1.add_courses('Git')
student2.add_courses('Python')
lecturer1.courses_attached += ['Python']
lecturer2.courses_attached += ['Python', 'Git']
reviewer1.courses_attached += ['Python']
reviewer2.courses_attached += ['Git']


reviewer1.rate_hw(student1, 'Python', 8)
reviewer1.rate_hw(student1, 'Python', 10)
reviewer2.rate_hw(student2, 'Git', 7)
student1.rate_lecturer(lecturer1, 'Python', 9)
student1.rate_lecturer(lecturer1, 'Python', 10)
student2.rate_lecturer(lecturer2, 'Python', 8)


print(student1)
print(student2)
print(lecturer1)
print(lecturer2)
print(reviewer1)
print(reviewer2)


def average_grade_all_student(students_list, course):
    grades_sum = 0
    grades_count = 0
    for student in students_list:
        if course in student.grades:
            grades_sum += sum(student.grades[course])
            grades_count += len(student.grades[course])
    return grades_sum / grades_count if grades_count else 0


def average_grade_all_lecturer(lecturers_list, course):
    grades_sum = 0
    grades_count = 0
    for lecturer in lecturers_list:
        if course in lecturer.grades:
            grades_sum += sum(lecturer.grades[course])
            grades_count += len(lecturer.grades[course])
    return grades_sum / grades_count if grades_count else 0


print(f"Средняя оценка студентов по Python: {average_grade_all_student([student1, student2], 'Python'):.1f}")
print(f"Средняя оценка лекторов по Python: {average_grade_all_lecturer([lecturer1, lecturer2], 'Python'):.1f}")

# %% [markdown]
# ## **Задание №4. Перегрузка операторов с помощью магических методов**

# %% [markdown]
# ### **Цель задания:**

# %% [markdown]
# Разработать класс `Fraction` для работы с рациональными числами (дробями), реализовав перегрузку стандартных операторов через переопределение соответствующих магических методов. Ваша задача — обеспечить класс `Fraction` функциональностью, демонстрируемой в приведенном примере кода.

# %% [markdown]
# ### **Описание задания:**

# %% [markdown]
# Создайте класс `Fraction`, который представляет собой обыкновенную дробь с числителем и знаменателем. Перегрузите основные арифметические операторы для выполнения операций над дробями, а также операторы сравнения. Обеспечьте возможность преобразования дроби в число с плавающей точкой и обратную операцию. Реализуйте обработку исключений при некорректных данных. Предоставьте понятное строковое и официальное представление дроби.

# %% [markdown]
# **Требования к заданию:**

# %% [markdown]
# 1. **Класс `Fraction` должен:**
#
#    - Инициализироваться двумя целыми числами: числителем и знаменателем.
#    - Обрабатывать ситуацию когда знаменатель равен нулю, а именно выводить сообщение `"Знаменатель не может быть нулем"`.
#    - Упрощать дроби до несократимых при создании и после каждой арифметической операции.
#
# 2. **Перегрузить следующие операторы путем переопределения магических методов:**
#
#    - **Сложение `+`** (`__add__`): сложение двух дробей, возвращает новую дробь.
#    - **Вычитание `-`** (`__sub__`): вычитание одной дроби из другой, возвращает новую дробь.
#    - **Умножение `*`** (`__mul__`): умножение двух дробей, возвращает новую дробь.
#    - **Деление `/`** (`__truediv__`): деление одной дроби на другую, возвращает новую дробь.
#    - **Равенство `==`** (`__eq__`): проверка равенства двух дробей.
#    - **Сравнения `>`, `<`, `>=`, `<=`**: сравнение дробей по их значению, реализовать методы `__lt__`, `__le__`, `__gt__`, `__ge__`.
#
# 3. **Реализовать преобразование типов:**
#
#    - **Метод `__float__`**: преобразование дроби в число с плавающей точкой.
#
# 4. **Дополнительные методы класса:**
#
#    - **`reciprocal()`**: возвращает новую дробь, обратную данной (числитель и знаменатель меняются местами).
#    - **Строковое представление** (`__str__`): возвращает строку вида `"числитель/знаменатель"`. Если знаменатель равен 1, возвращает только числитель в виде строки.
#    - **Официальное представление** (`__repr__`): возвращает строку вида `"Fraction(числитель, знаменатель)"`.
#
# 5. **Обработка исключений:**
#
#    - При попытке создать дробь с нулевым знаменателем выводить в консоль сообщение `ValueError`.
#    - При попытке деления на нулевую дробь, выводить в консоль сообщение `ZeroDivisionError`.
#
# 6. **Тестирование:**
#
#    - Написать код, демонстрирующий работу всех реализованных методов и операторов, используя примеры, приведенные ниже.
#    - Обеспечить корректную обработку исключений и вывод соответствующих сообщений.

# %%
import math

def gcd(a, b):
    """Находит наибольший общий делитель (НОД) двух чисел."""
    while b:
        a, b = b, a % b
    return a

class Fraction:
    def __init__(self, numerator, denominator):
        if denominator == 0:
            raise ValueError("Знаменатель не может быть нулем")
        common = gcd(abs(numerator), abs(denominator))
        self.numerator = numerator // common
        self.denominator = denominator // common

    def __add__(self, other):
        if not isinstance(other, Fraction):
          return NotImplemented
        num = self.numerator * other.denominator + other.numerator * self.denominator
        den = self.denominator * other.denominator
        return Fraction(num, den)

    def __sub__(self, other):
        if not isinstance(other, Fraction):
          return NotImplemented
        num = self.numerator * other.denominator - other.numerator * self.denominator
        den = self.denominator * other.denominator
        return Fraction(num, den)

    def __mul__(self, other):
        if not isinstance(other, Fraction):
          return NotImplemented
        num = self.numerator * other.numerator
        den = self.denominator * other.denominator
        return Fraction(num, den)

    def __truediv__(self, other):
        if not isinstance(other, Fraction):
          return NotImplemented
        if other.numerator == 0:
            raise ZeroDivisionError("Деление на ноль")
        num = self.numerator * other.denominator
        den = self.denominator * other.numerator
        return Fraction(num, den)

    def __eq__(self, other):
        if not isinstance(other, Fraction):
          return False
        return self.numerator * other.denominator == other.numerator * self.denominator

    def __lt__(self, other):
        if not isinstance(other, Fraction):
          return NotImplemented
        return self.numerator * other.denominator < other.numerator * self.denominator

    def __le__(self, other):
        if not isinstance(other, Fraction):
          return NotImplemented
        return self.numerator * other.denominator <= other.numerator * self.denominator

    def __gt__(self, other):
        if not isinstance(other, Fraction):
          return NotImplemented
        return self.numerator * other.denominator > other.numerator * self.denominator

    def __ge__(self, other):
        if not isinstance(other, Fraction):
          return NotImplemented
        return self.numerator * other.denominator >= other.numerator * self.denominator

    def __float__(self):
        return self.numerator / self.denominator

    def reciprocal(self):
        if self.numerator == 0:
            raise ZeroDivisionError("Обратная дробь от нуля не существует")
        return Fraction(self.denominator, self.numerator)

    def __str__(self):
        if self.denominator == 1:
            return str(self.numerator)
        return f"{self.numerator}/{self.denominator}"

    def __repr__(self):
        return f"Fraction({self.numerator}, {self.denominator})"


# Примеры использования
try:
    frac1 = Fraction(1, 2)
    frac2 = Fraction(3, 4)
    print(f"{frac1} + {frac2} = {frac1 + frac2}")  # 1/2 + 3/4 = 5/4
    print(f"{frac1} - {frac2} = {frac1 - frac2}")  # 1/2 - 3/4 = -1/4
    print(f"{frac1} * {frac2} = {frac1 * frac2}")  # 1/2 * 3/4 = 3/8
    print(f"{frac1} / {frac2} = {frac1 / frac2}")  # 1/2 / 3/4 = 2/3
    print(f"{frac1} == {frac2}: {frac1 == frac2}")  # 1/2 == 3/4: False
    print(f"{frac1} < {frac2}: {frac1 < frac2}")  # 1/2 < 3/4: True
    print(f"float({frac1}): {float(frac1)}")  # float(1/2): 0.5
    print(f"Обратная дробь {frac1}: {frac1.reciprocal()}")  # 2/1
    print(frac1)  # 1/2
    print(repr(frac1))  # Fraction(1, 2)

    frac3 = Fraction(0,1)
    frac4 = Fraction(1,0)

    print(frac3.reciprocal())
    print(frac1/frac3)

except (ValueError, ZeroDivisionError) as e:
    print(f"Ошибка: {e}")

# %% [markdown]
# **Тесты для класса `Fraction`:**

# %%
# Создание дробей
f1 = Fraction(3, 4)
f2 = Fraction(5, 6)

# Сложение дробей
f3 = f1 + f2
print(f3)  # Ожидаемый вывод: 19/12

# Вычитание дробей
f4 = f1 - f2
print(f4)  # Ожидаемый вывод: -1/12

# Умножение дробей
f5 = f1 * f2
print(f5)  # Ожидаемый вывод: 5/8

# Деление дробей
f6 = f1 / f2
print(f6)  # Ожидаемый вывод: 9/10

# Проверка равенства
print(f1 == Fraction(6, 8))   # Ожидаемый вывод: True

# Сравнение дробей
print(f1 > f2)    # Ожидаемый вывод: False
print(f1 < f2)    # Ожидаемый вывод: True

# Преобразование к float
print(float(f1))  # Ожидаемый вывод: 0.75

# Обратная дробь
f7 = f1.reciprocal()
print(f7)         # Ожидаемый вывод: 4/3

# Создание дроби из float
f8 = Fraction.from_float(0.75)
print(f8)         # Ожидаемый вывод: 3/4

# Проверка обработки исключений
try:
    f_invalid = Fraction(5, 0)
except ValueError as e:
    print(e)  # Ожидаемый вывод: Знаменатель не может быть нулем

# Строковое и официальное представление
print(str(f1))    # Ожидаемый вывод: 3/4
print(repr(f1))   # Ожидаемый вывод: Fraction(3, 4)
